# %%
import pandas as pd
import numpy as np
import re
import glob
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Import data

# %%
# Read all txt files into a panda dataframe
def importData():
   
    path='../input/data-science-for-good-city-of-los-angeles/cityofla/CityofLA/Job Bulletins/*.txt'
    files=glob.glob(path)
    jobs_list=[]
    file_names=[]
    for file in files:
        with open(file,'r',errors='replace') as f:
            jobs_list.append(f.read())
        match = re.search('Bulletins/(.*\.txt)',file)
        file_names.append(match.group(1))
    jobs_df = pd.DataFrame({"File_Name":file_names,"job_info":jobs_list})
    
    return jobs_df

# %% [markdown]
# # Extract data using regex

# %%
# Define functions for pandas dataframe apply

# Get job title (JOB_CLASS_TITLE)
def get_job_title(text):
    title = text.split('\n',1)[0]
    return title.strip()

# Get class code (JOB_CLASS_NO)
def get_class_code(text):
    match = re.search(r'Class\s*Code:\s*(\d+)',text)
    if match:
        return match.group(1)
    else:
        return None

    
# Get open date (OPEN_DATE)
def get_open_date(text):
    match = re.search(r'Open\s*Date:\s*(\d+-\d+-\d+)',text)
    if match:
        return match.group(1)
    else:
        return None

# Get exam type
def get_exam_type(text):
    match = re.search(r'(?s)Open\s*Date(.*?)ANNUAL\s*SALARY',text)
    if match:
        result = match.group(1)
        op=re.search(r'open',result,flags=re.IGNORECASE)
        open_int_prom=re.search(r'(open.*comp.*?tive)|(comp.*?tive.*open)',result,flags=re.IGNORECASE)
        int_dept_prom=re.search(r'inter.*?mental',result,flags=re.IGNORECASE)
        dept_prom=re.search(r'dep.*?mental',result,flags=re.IGNORECASE)
        if int_dept_prom:
            return 'INT_DEPT_PROM'
        elif dept_prom:
            return 'DEPT_PROM'
        elif open_int_prom:
            return 'OPEN_INT_PROM'
        elif op:
            return 'OPEN'
        else:
            return None
    else:
        return None
    
# Get general salary (ENTRY_SALARY_GEN)
def get_salary_gen(text):
    match = re.search(r'(?s)ANNUAL\s*SALARY(.*?)DUTIES.*',text)
    if match:
        result = match.group(1)
        sal=re.search(r'(\d+,\d+.*?to.*?\d+,\d+|\d+,\d+).*?Water.*Power',text,flags=re.IGNORECASE)\
                if get_salary_dwp(text) else re.search(r'(\d+,\d+.*?to.*?\d+,\d+|\d+,\d+)',text,flags=re.IGNORECASE)
        if sal:
            return sal.group(1).replace('to','-').replace('$','')
        else:
            return None
    else:
        return None


# Get DWP salary (ENTRY_SALARY_DWP)
def get_salary_dwp(text):
    match = re.search(r'(?s)ANNUAL\s*SALARY(.*?)DUTIES.*',text)
    if match:
        result = match.group(1)
        sal=re.search(r'Water.*Power.*?(\d+,\d+.*?to.*?\d+,\d+|\d+,\d+)',text)
        if sal:
            return sal.group(1).replace('$','').replace('to','-')
        else:
            return None 
    else:
        return None
    
# Get driver license req (DRIVERS_LICENSE_REQ)
def get_dl_req(text):
    match= re.search(r"(.*?)driver\'s license",text)    
    if match:
        result = match.group(1).lower().split()
        if 'may' in result:
            return 'P'
        else:
            return 'R'
    else:
        return None
    
# Get driver license type (DRIV_LIC_TYPE)
def get_dl_type(text):
    dl_types=[]
    match= re.search(r"(?s)(valid California Class|valid Class|valid California Commercial Class)(.*?)(California driver\'s license|driver\'s license)",text)
    if match:
        dl=match.group(2)
        if 'A' in dl:
            dl_types.append('A')
        if 'B' in dl:
            dl_types.append('B') 
        if 'C' in dl:
            dl_types.append('C')  
        if 'I' in dl:
            dl_types.append('I')   
        return ','.join(dl_types)
    else:
        return None

# Get duties (JOB_DUTIES)
def get_duties(text):
    match= re.search(r"(?s)DUTIES(.*?)(REQ.*?MENT|MINI.*?REQ)", text)
    if match:
        return match.group(1).strip()
    else:
        return None

# Get requirements section
def get_req_section(text):  
    match= re.search(r"(?s)(QUAL.*?TIONS*|REQ.*?MENTS*).*?\n(.*?)(PROCESS NOTES|NOTES|WHERE TO APPLY|HOW TO APPLY)", text)
    if match:
        return match.group(2).strip()
    else:
        return None

# Split requirements to rows
def split_req(df):
    req_list = df['Req_section'].apply(lambda x: re.split(r'or\s*\n+(?=\d\.)', x))
    df = pd.DataFrame({col:np.repeat(df[col].values, req_list.str.len()) \
                  for col in df.columns})
    df['req_list'] = np.concatenate(req_list.values)

    return df
    
    
# Extract all by regex
def extract_df(df):    
    # JOB_CLASS_TITLE
    df['JOB_CLASS_TITLE'] = df['job_info'].apply(lambda x: get_job_title(x))
    # JOB_CLASS_NO
    df['JOB_CLASS_NO'] = df['job_info'].apply(lambda x: get_class_code(x))
    # OPEN_DATE
    df['OPEN_DATE'] = df['job_info'].apply(lambda x: get_open_date(x))
    # EXAM_TYPE
    df['EXAM_TYPE'] = df['job_info'].apply(lambda x: get_exam_type(x))
    # ENTRY_SALARY_GEN
    df['ENTRY_SALARY_GEN'] = df['job_info'].apply(lambda x: get_salary_gen(x))
    # ENTRY_SALARY_DWP
    df['ENTRY_SALARY_DWP'] = df['job_info'].apply(lambda x: get_salary_dwp(x))
    # JOB_DUTIES
    df['JOB_DUTIES'] = df['job_info'].apply(lambda x: get_duties(x))
    # DRIVERS_LICENSE_REQ
    df['DRIVERS_LICENSE_REQ'] = df['job_info'].apply(lambda x: get_dl_req(x))
    # DRIV_LIC_TYPE
    df['DRIV_LIC_TYPE'] = df['job_info'].apply(lambda x: get_dl_type(x))
    # Requirements section
    df['Req_section'] = df['job_info'].apply(lambda x: get_req_section(x))
    # Split reqs
    df = split_req(df)
    # Add req_set_id
    df['REQUIREMENT_SET_ID'] = df.groupby('JOB_CLASS_NO').cumcount() + 1
    
    return df

# %%
# Perform the extraction
df = importData()
df = extract_df(df)
df.head(10)
# Out:
#                                            File_Name  \
# 0        PARK MAINTENANCE SUPERVISOR 3145 102618.txt
# 1        PARK MAINTENANCE SUPERVISOR 3145 102618.txt
# 2  ENVIRONMENTAL ENGINEER  7872 082616 REV 090116...
# 3  MOTION PICTURE AND TELEVISION MANAGER 1789 111...
# 4               HOUSING INVESTIGATOR 8516 062918.txt
# 5               HOUSING INVESTIGATOR 8516 062918.txt
# 6               HOUSING INVESTIGATOR 8516 062918.txt
# 7  DEPARTMENTAL CHIEF ACCOUNTANT 1593 111717 revi...
# 8                  POLICE LIEUTENANT 2232 020918.txt
# 9                        AUDITOR 1517 031816 (1).txt
#
#                                             job_info  \
# 0  PARK MAINTENANCE SUPERVISOR\n\nClass Code:    ...
# 1  PARK MAINTENANCE SUPERVISOR\n\nClass Code:    ...
# 2  ENVIRONMENTAL ENGINEER \n\nClass Code:       7...
# 3  MOTION PICTURE AND TELEVISION MANAGER\n\n\nCla...
# 4  HOUSING INVESTIGATOR\n\nClass Code:       8516...
# 5  HOUSING INVESTIGATOR\n\nClass Code:       8516...
# 6  HOUSING INVESTIGATOR\n\nClass Code:       8516...
# 7  DEPARTMENTAL CHIEF ACCOUNTANT\n\n             ...
# 8  POLICE LIEUTENANT\n  Class Code: 2232         ...
# 9  AUDITOR\nClass Code:        1517\nOpen Date:  ...
#
#                          JOB_CLASS_TITLE JOB_CLASS_NO OPEN_DATE EXAM_TYPE  \
# 0            PARK MAINTENANCE SUPERVISOR         3145  10-26-18      OPEN
# 1            PARK MAINTENANCE SUPERVISOR         3145  10-26-18      OPEN
# 2                 ENVIRONMENTAL ENGINEER         7872  08-26-16      OPEN
# 3  MOTION PICTURE AND TELEVISION MANAGER         1789  11-17-17      OPEN
# 4                   HOUSING INVESTIGATOR         8516  06-29-18      OPEN
# 5                   HOUSING INVESTIGATOR         8516  06-29-18      OPEN
# 6                   HOUSING INVESTIGATOR         8516  06-29-18      OPEN
# 7          DEPARTMENTAL CHIEF ACCOUNTANT         1593  11-17-17      OPEN
# 8                      POLICE LIEUTENANT         2232  02-09-18      OPEN
# 9                                AUDITOR         1517  03-18-16      OPEN
#
#     ENTRY_SALARY_GEN ENTRY_SALARY_DWP  \
# 0               None  83,728 - 88,405
# 1               None  83,728 - 88,405
# 2   89,637 - 127,555             None
# 3  120,080 - 175,559             None
# 4    59,487 - 86,965             None
# 5    59,487 - 86,965             None
# 6    59,487 - 86,965             None
# 7   91,913 - 130,771             None
# 8  125,572 - 139,916             None
# 9    54,455 - 79,594             None
#
#                                           JOB_DUTIES DRIVERS_LICENSE_REQ  \
# 0  A Park Maintenance Supervisor directly supervi...                   R
# 1  A Park Maintenance Supervisor directly supervi...                   R
# 2  An Environmental Engineer performs responsible...                   R
# 3  A Motion Picture and Television Manager plans,...                   R
# 4  A Housing Investigator conducts preliminary an...                   R
# 5  A Housing Investigator conducts preliminary an...                   R
# 6  A Housing Investigator conducts preliminary an...                   R
# 7  A Departmental Chief Accountant plans and dire...                None
# 8  A Police Lieutenant plans, organizes, and dire...                None
# 9  An Auditor conducts audits of financial and in...                   P
#
#   DRIV_LIC_TYPE                                        Req_section  \
# 0          None  1. Two years of full-time paid experience as a...
# 1          None  1. Two years of full-time paid experience as a...
# 2          None  Two years of full-time paid professional envir...
# 3          None  1. Graduation from an accredited four-year col...
# 4          None  1. Graduation from an accredited four-year col...
# 5          None  1. Graduation from an accredited four-year col...
# 6          None  1. Graduation from an accredited four-year col...
# 7          None  Two years of full-time paid professional accou...
# 8          None  1. Two years as a Police Sergeant, Police Dete...
# 9          None  1. One year of full-time paid professional exp...
#
#                                             req_list  REQUIREMENT_SET_ID
# 0  1. Two years of full-time paid experience as a...                   1
# 1  2. One year full-time paid experience as noted...                   2
# 2  Two years of full-time paid professional envir...                   1
# 3  1. Graduation from an accredited four-year col...                   1
# 4  1. Graduation from an accredited four-year col...                   1
# 5  2. A paralegal certificate from a paralegal tr...                   2
# 6  3. Four years of full-time paid experience inv...                   3
# 7  Two years of full-time paid professional accou...                   1
# 8  1. Two years as a Police Sergeant, Police Dete...                   1
# 9  1. One year of full-time paid professional exp...                   1

# %% [markdown]
# # Extract data using NER in spaCy

# %% [markdown]
# ## Generate spacy training data

# %%
import logging
import json
# Convert json to spacy training data structure
def json_to_spacy(filePath):
    try:
        training_data = []
        lines=[]
        with open(filePath, 'r') as f:
            lines = f.readlines()

        for line in lines:
            data = json.loads(line)
            text = data['content']
            entities = []
            for annotation in data['annotation']:
                #only a single point in text annotation.
                point = annotation['points'][0]
                labels = annotation['label']
                # handle both list of labels or a single label.
                if not isinstance(labels, list):
                    labels = [labels]

                for label in labels:
                    #dataturks indices are both inclusive [start, end] but spacy is not [start, end)
                    entities.append((point['start'], point['end'] + 1 ,label))


            training_data.append((text, {"entities" : entities}))

        return training_data
    except Exception as e:
        logging.exception("Unable to process " + filePath + "\n" + "error = " + str(e))
        return None
    
# Create spacy training data
train_data = json_to_spacy('../input/ner-annotation-of-city-of-la-jobs/city_la_jobs_ner_labeling.json')

# %% [markdown]
# ## Train NER model

# %%
import random
import spacy

# Model training function
def ner_model(train_data, n_iter=50):
    
    # Create Ner model and add labels
    nlp = spacy.blank("en")
    ner = nlp.create_pipe("ner")
    nlp.add_pipe(ner, last=True)
    for _, annotations in train_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])
    
    # Begin training
    nlp.begin_training()
    
    for itn in range(n_iter):
        random.shuffle(train_data)
        losses = {}
        batches = spacy.util.minibatch(train_data, size=spacy.util.compounding(4.0, 32.0, 1.001))
        for batch in batches:
            texts, annotations = zip(*batch)
            nlp.update(texts,annotations,drop=0.5,losses=losses)
        if itn%10==0:
            print(losses)
    return nlp

nlp = ner_model(train_data)
nlp.to_disk('./')
# Out:
# {'ner': 5367.079756039195}
# {'ner': 3404.516049408646}
# {'ner': 1993.4781608458325}
# {'ner': 1909.0222931467833}
# {'ner': 1862.9048940600162}

# %%
# Test the model with predictions
for text, _ in train_data:
    doc = nlp(text)
    print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
    print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('Four years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('collection or disposal of municipal wastes', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('Four', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('in', '', 2), ('connection', '', 2), ('with', '', 2), ('the', '', 2), ('collection', 'EXP_JOB_CLASS_FUNCTION', 3), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('disposal', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('municipal', 'EXP_JOB_CLASS_FUNCTION', 1), ('wastes', 'EXP_JOB_CLASS_FUNCTION', 1), ('.', '', 2), ('Completion', '', 2), ('of', '', 2), ('30', '', 2), ('semester', '', 2), ('or', '', 2), ('45', '', 2), ('quarter', '', 2), ('units', '', 2), ('in', '', 2), ('an', '', 2), ('accredited', '', 2), ('college', '', 2), ('or', '', 2), ('university', '', 2), ('may', '', 2), ('be', '', 2), ('substituted', '', 2), ('on', '', 2), ('a', '', 2), ('year', '', 2), ('-', '', 2), ('for', '', 2), ('-', '', 2), ('year', '', 2), ('basis', '', 2), ('for', '', 2), ('the', '', 2), ('above', '', 2), ('experience', '', 2), ('up', '', 2), ('to', '', 2), ('a', '', 2), ('maximum', '', 2), ('of', '', 2), ('two', '', 2), ('years', '', 2), ('.', '', 2)]
# Entities [('four-year', 'EDUCATION_YEARS'), ('college or university', 'SCHOOL_TYPE'), ("Bachelor's Degree or Master", 'DEGREE NAME'), ('health science', 'EDUCATION_MAJOR'), ('four-year', 'EDUCATION_YEARS'), ('college or university', 'SCHOOL_TYPE'), ('one year', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('enforcement of Federal OSHA, CAL/OSHA or any state OSHA regulations which includes facility or field inspections and the development of safety programs', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('"', '', 2), ('1', '', 2), ('.', '', 2), ('Graduation', '', 2), ('from', '', 2), ('an', '', 2), ('accredited', '', 2), ('four', 'EDUCATION_YEARS', 3), ('-', 'EDUCATION_YEARS', 1), ('year', 'EDUCATION_YEARS', 1), ('college', 'SCHOOL_TYPE', 3), ('or', 'SCHOOL_TYPE', 1), ('university', 'SCHOOL_TYPE', 1), ('with', '', 2), ('a', '', 2), ('Bachelor', 'DEGREE NAME', 3), ("'s", 'DEGREE NAME', 1), ('Degree', 'DEGREE NAME', 1), ('or', 'DEGREE NAME', 1), ('Master', 'DEGREE NAME', 1), ("'s", '', 2), ('Degree', '', 2), ('in', '', 2), ('occupational', '', 2), ('health', 'EDUCATION_MAJOR', 3), ('science', 'EDUCATION_MAJOR', 1), (',', '', 2), ('health', '', 2), ('and', '', 2), ('safety', '', 2), ('studies', '', 2), ('or', '', 2), ('a', '', 2), ('closely', '', 2), ('related', '', 2), ('field', '', 2), (';', '', 2), ('or', '', 2), ('2', '', 2), ('.', '', 2), ('Graduation', '', 2), ('from', '', 2), ('an', '', 2), ('accredited', '', 2), ('four', 'EDUCATION_YEARS', 3), ('-', 'EDUCATION_YEARS', 1), ('year', 'EDUCATION_YEARS', 1), ('college', 'SCHOOL_TYPE', 3), ('or', 'SCHOOL_TYPE', 1), ('university', 'SCHOOL_TYPE', 1), ('and', '', 2), ('one', 'EXPERIENCE_LENGTH', 3), ('year', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('professional', '', 2), ('safety', '', 2), ('experience', '', 2), ('in', '', 2), ('the', '', 2), ('enforcement', 'EXP_JOB_CLASS_FUNCTION', 3), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('Federal', 'EXP_JOB_CLASS_FUNCTION', 1), ('OSHA', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('CAL', 'EXP_JOB_CLASS_FUNCTION', 1), ('/', 'EXP_JOB_CLASS_FUNCTION', 1), ('OSHA', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('any', 'EXP_JOB_CLASS_FUNCTION', 1), ('state', 'EXP_JOB_CLASS_FUNCTION', 1), ('OSHA', 'EXP_JOB_CLASS_FUNCTION', 1), ('regulations', 'EXP_JOB_CLASS_FUNCTION', 1), ('which', 'EXP_JOB_CLASS_FUNCTION', 1), ('includes', 'EXP_JOB_CLASS_FUNCTION', 1), ('facility', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('field', 'EXP_JOB_CLASS_FUNCTION', 1), ('inspections', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('the', 'EXP_JOB_CLASS_FUNCTION', 1), ('development', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('safety', 'EXP_JOB_CLASS_FUNCTION', 1), ('programs', 'EXP_JOB_CLASS_FUNCTION', 1), ('.', '', 2), (' ', '', 2), ('"', '', 2)]
# Entities [('Vocational Worker', 'EXP_JOB_CLASS_TITLE'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('services, lubricates, and performs other non-repair servicing of automotive vehicles', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('"', '', 2), ('1', '', 2), ('.', '', 2), ('Current', '', 2), ('employment', '', 2), ('as', '', 2), ('a', '', 2), ('Vocational', 'EXP_JOB_CLASS_TITLE', 3), ('Worker', 'EXP_JOB_CLASS_TITLE', 1), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('in', '', 2), ('a', '', 2), ('position', '', 2), ('that', '', 2), ('services', 'EXP_JOB_CLASS_FUNCTION', 3), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('lubricates', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('performs', 'EXP_JOB_CLASS_FUNCTION', 1), ('other', 'EXP_JOB_CLASS_FUNCTION', 1), ('non', 'EXP_JOB_CLASS_FUNCTION', 1), ('-', 'EXP_JOB_CLASS_FUNCTION', 1), ('repair', 'EXP_JOB_CLASS_FUNCTION', 1), ('servicing', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('automotive', 'EXP_JOB_CLASS_FUNCTION', 1), ('vehicles', 'EXP_JOB_CLASS_FUNCTION', 1), (';', '', 2), ('and', '', 2), ('2', '', 2), ('.', '', 2), ('A', '', 2), ('letter', '', 2), ('of', '', 2), ('recommendation', '', 2), ('from', '', 2), ('the', '', 2), ('personnel', '', 2), ('office', '', 2), ('of', '', 2), ('the', '', 2), ('employing', '', 2), ('department', '', 2), (',', '', 2), ('which', '', 2), ('includes', '', 2), ('a', '', 2), ('statement', '', 2), ('of', '', 2), ('the', '', 2), ('department', '', 2
', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Geographic Information Systems Specialist', 'EXP_JOB_CLASS_TITLE'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('Two years', 'EXPERIENCE_LENGTH'), ('Geographic Information Systems Specialist', 'EXP_JOB_CLASS_TITLE'), ('full-time', 'FULL_TIME_PART_TIME'), ('operation of ArcGIS, ArcGIS Pro, or a similar geographic information systems software which incorporates a Relational Database Management System (RDBMS)', 'EXP_JOB_CLASS_FUNCTION'), ('Two years', 'EXPERIENCE_LENGTH'), ('full time paid', 'FULL_TIME_PART_TIME')]
# Tokens [('"', '', 2), ('1', '', 2), ('.', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('Geographic', 'EXP_JOB_CLASS_TITLE', 3), ('Information', 'EXP_JOB_CLASS_TITLE', 1), ('Systems', 'EXP_JOB_CLASS_TITLE', 1), ('Specialist', 'EXP_JOB_CLASS_TITLE', 1), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), (',', '', 2), ('or', '', 2), ('2', '', 2), ('.', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('in', '', 2), ('a', '', 2), ('class', '', 2), ('at', '', 2), ('the', '', 2), ('level', '', 2), ('of', '', 2), ('Geographic', 'EXP_JOB_CLASS_TITLE', 3), ('Information', 'EXP_JOB_CLASS_TITLE', 1), ('Systems', 'EXP_JOB_CLASS_TITLE', 1), ('Specialist', 'EXP_JOB_CLASS_TITLE', 1), (',', '', 2), ('which', '', 2), ('provides', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('in', '', 2), ('the', '', 2), ('operation', 'EXP_JOB_CLASS_FUNCTION', 3), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('ArcGIS', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('ArcGIS', 'EXP_JOB_CLASS_FUNCTION', 1), ('Pro', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('a', 'EXP_JOB_CLASS_FUNCTION', 1), ('similar', 'EXP_JOB_CLASS_FUNCTION', 1), ('geographic', 'EXP_JOB_CLASS_FUNCTION', 1), ('information', 'EXP_JOB_CLASS_FUNCTION', 1), ('systems', 'EXP_JOB_CLASS_FUNCTION', 1), ('software', 'EXP_JOB_CLASS_FUNCTION', 1), ('which', 'EXP_JOB_CLASS_FUNCTION', 1), ('incorporates', 'EXP_JOB_CLASS_FUNCTION', 1), ('a', 'EXP_JOB_CLASS_FUNCTION', 1), ('Relational', 'EXP_JOB_CLASS_FUNCTION', 1), ('Database', 'EXP_JOB_CLASS_FUNCTION', 1), ('Management', 'EXP_JOB_CLASS_FUNCTION', 1), ('System', 'EXP_JOB_CLASS_FUNCTION', 1), ('(', 'EXP_JOB_CLASS_FUNCTION', 1), ('RDBMS', 'EXP_JOB_CL
('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('in', '', 2), ('reading', 'EXP_JOB_CLASS_FUNCTION', 3), ('meters', 'EXP_JOB_CLASS_FUNCTION', 1), ('for', 'EXP_JOB_CLASS_FUNCTION', 1), ('a', 'EXP_JOB_CLASS_FUNCTION', 1), ('utility', 'EXP_JOB_CLASS_FUNCTION', 1), ('.', '', 2)]
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Heating and Refrigeration Inspector', 'EXP_JOB_CLASS_TITLE'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('full-time', 'FULL_TIME_PART_TIME'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('four-year', 'EDUCATION_YEARS'), ('college or university', 'SCHOOL_TYPE'), ('Industrial Technology, Industrial Science or special degree program in Construction Management, Construction Technology or Inspection Technology', 'EDUCATION_MAJOR')]
# Tokens [('"', '', 2), ('1', '', 2), ('.', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('Heating', 'EXP_JOB_CLASS_TITLE', 3), ('and', 'EXP_JOB_CLASS_TITLE', 1), ('Refrigeration', 'EXP_JOB_CLASS_TITLE', 1), ('Inspector', 'EXP_JOB_CLASS_TITLE', 1), ('for', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('.', '', 2), ('2', '', 2), ('.', '', 2), ('a.', '', 2), ('One', '', 2), ('year', '', 2), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('Building', '', 2), ('Mechanical', '', 2), ('Inspector', '', 2), ('for', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('may', '', 2), ('be', '', 2), ('substituted', '', 2), ('for', '', 2), ('one', '', 2), ('year', '', 2), ('of', '', 2), ('Heating', '', 2), ('and', '', 2), ('Refrigeration', '', 2), ('experience', '', 2), ('lacking', '', 2), (';', '', 2), ('or', '', 2), ('b.', '', 2), ('Graduation', '', 2), ('from', '', 2), ('a', '', 2), ('recognized', '', 2), ('four', 'EDUCATION_YEARS', 3), ('-', 'EDUCATION_YEARS', 1), ('year', 'EDUCATION_YEARS', 1), ('college', 'SCHOOL_TYPE', 3), ('or', 'SCHOOL_TYPE', 1), ('university', 'SCHOOL_TYPE', 1), ('with', '', 2), ('a', '', 2), ('degree', '', 2), ('in', '', 2), ('Industrial', 'EDUCATION_MAJOR', 3), ('Technology', 'EDUCATION_MAJOR', 1), (',', 'EDUCATION_MAJOR', 1), ('Industrial', 'EDUCATION_MAJOR', 1), ('Science', 'EDUCATION_MAJOR', 1), ('or', 'EDUCATION_MAJOR', 1), ('special', 'EDUCATION_MAJOR', 1), ('degree', 'EDUCATION_MAJOR', 1), ('program', 'EDUCATION_MAJOR', 1), ('in', 'EDUCATION_MAJOR', 1), ('Construction', 'EDUCATION_MAJOR', 1), ('Management', 'EDUCATION_MAJOR', 1), (',', 'EDUCATION_MAJOR', 1), ('Construction', 'EDUCATION_MAJOR', 1), ('Technology', 'EDUCATION_MAJOR', 1), ('or', 'EDUCATION_MAJOR', 1), ('Inspection', 'EDUCATION_MAJOR', 1), ('Technology', 'EDUCATION_MAJOR', 1), ('may', '', 2), ('be', '', 2), ('substituted', '', 2), ('for', '', 2), ('up', '', 2), ('to', '', 2), ('one', '', 2), ('year', '', 2), ('of', '', 2), ('required', '', 2), ('Heating', '', 2), ('and', '', 2), ('Refrigeration', '', 2), ('Inspector', '', 2), ('experience', '', 2), ('.', '', 2), ('"', '', 2)]
# Entities [('Three years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Senior Mechanical Engineering Drafting Technician', 'EXP_JOB_CLASS_TITLE'), ('City of Los Angeles', 'EXP_JOB_COMPANY')]
# Tokens [('"', '', 2), ('Three', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('Senior', 'EXP_JOB_CLASS_TITLE', 3), ('Mechanical', 'EXP_JOB_CLASS_TITLE', 1), ('Engineering', 'EXP_JOB_CLASS_TITLE', 1), ('Drafting', 'EXP_JOB_CLASS_TITLE', 1), ('Technician', 'EXP_JOB_CLASS_TITLE', 1), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('.', '', 2), ('NOTE', '', 2), (':', '', 2), ('Applicants', '', 2), ('who', '', 2), ('lack', '', 2), ('six', '', 2), ('months', '', 2), ('or', '', 2), ('less', '', 2), ('of', '', 2), ('the', '', 2), ('required', '', 2), ('experience', '', 2), ('may', '', 2), ('file', '', 2), ('for', '', 2), ('this', '', 2), ('examination', '', 2), ('.', '', 2), ('However', '', 2), (',', '', 2), ('they', '', 2), ('can', '', 2), ('not', '', 2), ('be', '', 2), ('appointed', '', 2), ('until', '', 2), ('the', '', 2), ('full', '', 2), ('experience', '', 2), ('requirement', '', 2), ('is', '', 2), ('met', '', 2), ('.', '', 2), ('"', '', 2)]
# Entities [('Three years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Survey Party Chief', 'EXP_JOB_CLASS_TITLE'), ('supervising employees engaged in engineering survey work', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('Three', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('at', '', 2), ('the', '', 2), ('level', '', 2), ('of', '', 2), ('Survey', 'EXP_JOB_CLASS_TITLE', 3), ('Party', 'EXP_JOB_CLASS_TITLE', 1), ('Chief', 'EXP_JOB_CLASS_TITLE', 1), ('supervising', 'EXP_JOB_CLASS_FUNCTION', 3), ('employees', 'EXP_JOB_CLASS_FUNCTION', 1), ('engaged', 'EXP_JOB_CLASS_FUNCTION', 1), ('in', 'EXP_JOB_CLASS_FUNCTION', 1), ('engineering', 'EXP_JOB_CLASS_FUNCTION', 1), ('survey', 'EXP_JOB_CLASS_FUNCTION', 1), ('work', 'EXP_JOB_CLASS_FUNCTION', 1), ('.', '', 2)]
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Senior Civil Engineer', 'EXP_JOB_CLASS_TITLE'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('Project Manager II', 'EXP_JOB_CLASS_TITLE')]
# Tokens [('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('professional', '', 2), ('engineering', '', 2), ('experience', '', 2), ('at', '', 2), ('the', '', 2), ('level', '', 2), ('of', '', 2), ('Senior', 'EXP_JOB_CLASS_TITLE', 3), ('Civil', 'EXP_JOB_CLASS_TITLE', 1), ('Engineer', 'EXP_JOB_CLASS_TITLE', 1), ('or', '', 2), ('in', '', 2), ('a', '', 2), ('position', '', 2), ('in', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('designated', '', 2), ('as', '', 2), ('a', '', 2), ('Project', 'EXP_JOB_CLASS_TITLE', 3), ('Manager', 'EXP_JOB_CLASS_TITLE', 1), ('II', 'EXP_JOB_CLASS_TITLE', 1), ('or', '', 2), ('III', '', 2), ('receiving', '', 2), ('the', '', 2), ('appropriate', '', 2), ('salary', '', 2), ('bonus', '', 2), ('.', '', 2)]
# Entities [('Six years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Senior Park Services Attendant', 'EXP_JOB_CLASS_TITLE'), ('operation of commercial, amusement, or service facilities', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('"', '', 2), ('Six', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('supervisory', '', 2), ('experience', '', 2), ('in', '', 2), ('a', '', 2), ('class', '', 2), ('at', '', 2), ('least', '', 2), ('at', '', 2), ('the', '', 2), ('level', '', 2), ('of', '', 2), ('Senior', 'EXP_JOB_CLASS_TITLE', 3), ('Park', 'EXP_JOB_CLASS_TITLE', 1), ('Services', 'EXP_JOB_CLASS_TITLE', 1), ('Attendant', 'EXP_JOB_CLASS_TITLE', 1), ('in', '', 2), ('the', '', 2), ('operation', 'EXP_JOB_CLASS_FUNCTION', 3), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('commercial', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('amusement', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('service', 'EXP_JOB_CLASS_FUNCTION', 1), ('facilities', 'EXP_JOB_CLASS_FUNCTION', 1), ('.', '', 2), (' ', '', 2), ('"', '', 2)]
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('Security Officer', 'EXP_JOB_CLASS_TITLE'), ('patrolling and safeguarding buildings, facilities, parks, grounds and equipment, and protecting restricted areas, or working in a law enforcement capacity', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('"', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('in', '', 2), ('a', '', 2), ('class', '', 2), ('at', '', 2), ('the', '', 2), ('level', '', 2), ('of', '', 2), ('Security', 'EXP_JOB_CLASS_TITLE', 3), ('Officer', 'EXP_JOB_CLASS_TITLE', 1), ('patrolling', 'EXP_JOB_CLASS_FUNCTION', 3), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('safeguarding', 'EXP_JOB_CLASS_FUNCTION', 1), ('buildings', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('facilities', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('parks', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('grounds', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('equipment', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('protecting', 'EXP_JOB_CLASS_FUNCTION', 1), ('restricted', 'EXP_JOB_CLASS_FUNCTION', 1), ('areas', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('working', 'EXP_JOB_CLASS_FUNCTION', 1), ('in', 'EXP_JOB_CLASS_FUNCTION', 1), ('a', 'EXP_JOB_CLASS_FUNCTION', 1), ('law', 'EXP_JOB_CLASS_FUNCTION', 1), ('enforcement', 'EXP_JOB_CLASS_FUNCTION', 1), ('capacity', 'EXP_JOB_CLASS_FUNCTION', 1), ('.', '', 2), (' ', '', 2), ('"', '', 2)]
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Wastewater Treatment Mechanic', 'EXP_JOB_CLASS_TITLE'), ('Senior Mechanical Repairer', 'EXP_JOB_CLASS_TITLE'), ('maintenance and repair of wastewater treatment and collection equipment such as wastewater process pumps, blowers, compressors,', 'EXP_JOB_CLASS_FUNCTION'), ('Four years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Mechanical Repairer', 'EXP_JOB_CLASS_TITLE'), ('assisting in the maintenance and repair of wastewater treatment and collection equipment such as wastewater process pumps, blowers, compressors,', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('"', '', 2), ('1', '', 2), ('.', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('Wastewater', 'EXP_JOB_CLASS_TITLE', 3), ('Treatment', 'EXP_JOB_CLASS_TITLE', 1), ('Mechanic', 'EXP_JOB_CLASS_TITLE', 1), ('or', '', 2), ('in', '', 2), ('a', '', 2), ('class', '', 2), ('at', '', 2), ('the', '', 2), ('level', '', 2), ('of', '', 2), ('Senior', 'EXP_JOB_CLASS_TITLE', 3), ('Mechanical', 'EXP_JOB_CLASS_TITLE', 1), ('Repairer', 'EXP_JOB_CLASS_TITLE', 1), ('in', '', 2), ('the', '', 2), ('maintenance', 'EXP_JOB_CLASS_FUNCTION', 3), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('repair', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('wastewater', 'EXP_JOB_CLASS_FUNCTION', 1), ('treatment', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('collection', 'EXP_JOB_CLASS_FUNCTION', 1), ('equipment', 'EXP_JOB_CLASS_FUNCTION', 1), ('such', 'EXP_JOB_CLASS_FUNCTION', 1), ('as', 'EXP_JOB_CLASS_FUNCTION', 1), ('wastewater', 'EXP_JOB_CLASS_FUNCTION', 1), ('process', 'EXP_JOB_CLASS_FUNCTION', 1), ('pumps', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('blowers', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('compressors', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('tanks', '', 2), (',', '', 2), ('drive', '', 2), ('chains', '', 2), (',', '', 2), ('flights', '', 2), (',', '', 2), ('aerating', '', 2), ('equipment', '', 2), (',', '', 2), ('or', '', 2), ('solids', '', 2), ('handling', '', 2), ('equipment', '', 2), (';', '', 2), ('or', '', 2), ('2', '', 2), ('.', '', 2), ('Four', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('Mechanical', 'EXP_JOB_CLASS_TITLE', 3), ('Repairer', 'EXP_JOB_CLASS_TITLE', 1), (',', '', 2), ('assisting', 'EXP_JOB_CLASS_FUNCTION', 3), ('in', 'EXP_JOB_CLASS_FUNCTION', 1), ('the', 'EXP_JOB_CLASS_FUNCTION', 1), ('maintenance', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('repair', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('wastewater', 'EXP_JOB_CLASS_FUNCTION', 1), ('treatment', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('collection', 'EXP_JOB_CLASS_FUNCTION', 1), ('equipment', 'EXP_JOB_CLASS_FUNCTION', 1), ('such', 'EXP_JOB_CLASS_FUNCTION', 1), ('as', 'EXP_JOB_CLASS_FUNCTION', 1), ('wastewater', 'EXP_JOB_CLASS_FUNCTION', 1), ('process', 'EXP_JOB_CLASS_FUNCTION', 1), ('pumps', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('blowers', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('compressors', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('tanks', '', 2), (',', '', 2), ('drive', '', 2), ('chains', '', 2), (',', '', 2), ('flights', '', 2), (',', '', 2), ('aerating', '', 2), ('equipment', '', 2), (',', '', 2), ('or', '', 2), ('solids', '', 2), ('handling', '', 2), ('equipment', '', 2), ('.', '', 2), (' ', '', 2), ('"', '', 2)]
# Entities [('Four years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('journey-level boilermaker', 'EXP_JOB_CLASS_TITLE'), ('engaged in the assembly, installation, repair and maintenance of boilers and pressure vessels made of steel plate', 'EXP_JOB_CLASS_FUNCTION'), ('Four years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('journey-level welder', 'EXP_JOB_CLASS_TITLE'), ('engaged in the assembly, installation, repair and maintenance of boilers and pressure vessels made of steel plate', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('"', '', 2), ('1', '', 2), ('.', '', 2), ('Four', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('journey', 'EXP_JOB_CLASS_TITLE', 3), ('-', 'EXP_JOB_CLASS_TITLE', 1), ('level', 'EXP_JOB_CLASS_TITLE', 1), ('boilermaker', 'EXP_JOB_CLASS_TITLE', 1), ('engaged', 'EXP_JOB_CLASS_FUNCTION', 3), ('in', 'EXP_JOB_CLASS_FUNCTION', 1), ('the', 'EXP_JOB_CLASS_FUNCTION', 1), ('assembly', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('installation', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('repair', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('maintenance', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('boilers', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('pressure', 'EXP_JOB_CLASS_FUNCTION', 1), ('vessels', 'EXP_JOB_CLASS_FUNCTION', 1), ('made', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('steel', 'EXP_JOB_CLASS_FUNCTION', 1), ('plate', 'EXP_JOB_CLASS_FUNCTION', 1), (';', '', 2), ('or', '', 2), ('2', '', 2), ('.', '', 2), ('Four', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('journey', 'EXP_JOB_CLASS_TITLE', 3), ('-', 'EXP_JOB_CLASS_TITLE', 1), ('level', 'EXP_JOB_CLASS_TITLE', 1), ('welder', 'EXP_JOB_CLASS_TITLE', 1), ('certified', '', 2), ('under', '', 2), ('ASME', '', 2), ('Boiler', '', 2), ('and', '', 2), ('Pressure', '', 2), ('Vessel', '', 2), ('Code', '', 2), ('Section', '', 2), ('IX', '', 2), ('engaged', 'EXP_JOB_CLASS_FUNCTION', 3), ('in', 'EXP_JOB_CLASS_FUNCTION', 1), ('the', 'EXP_JOB_CLASS_FUNCTION', 1), ('assembly', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('installation', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('repair', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('maintenance', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('boilers', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('pressure', 'EXP_JOB_CLASS_FUNCTION', 1), ('vessels', 'EXP_JOB_CLASS_FUNCTION', 1), ('made', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('steel', 'EXP_JOB_CLASS_FUNCTION', 1), ('plate', 'EXP_JOB_CLASS_FUNCTION', 1), ('.', '', 2), ('"', '', 2)]
# Entities [('Five years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('police officer', 'EXP_JOB_CLASS_TITLE'), ('1000 cumulative hours', 'EXPERIENCE_LENGTH'), ('part-time', 'FULL_TIME_PART_TIME'), ('Background Investigator', 'EXP_JOB_CLASS_TITLE'), ('City of Los Angeles', 'EXP_JOB_COMPANY')]
# Tokens [('1', '', 2), ('.', '', 2), ('Five', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('within', '', 2), ('the', '', 2), ('last', '', 2), ('ten', '', 2), ('years', '', 2), ('as', '', 2), ('a', '', 2), ('police', 'EXP_JOB_CLASS_TITLE', 3), ('officer', 'EXP_JOB_CLASS_TITLE', 1), (';', '', 2), ('or', '', 2), ('2', '', 2), ('.', '', 2), ('1000', 'EXPERIENCE_LENGTH', 3), ('cumulative', 'EXPERIENCE_LENGTH', 1), ('hours', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('part', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('within', '', 2), ('the', '', 2), ('last', '', 2), ('five', '', 2), ('years', '', 2), ('as', '', 2), ('a', '', 2), ('Background', 'EXP_JOB_CLASS_TITLE', 3), ('Investigator', 'EXP_JOB_CLASS_TITLE', 1), ('employed', '', 2), ('by', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('.', '', 2)]
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Building Inspector', 'EXP_JOB_CLASS_TITLE'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('One year', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Building Mechanical Inspector', 'EXP_JOB_CLASS_TITLE'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('four-year', 'EDUCATION_YEARS'), ('college or university', 'SCHOOL_TYPE'), ('Industrial Technology, Industrial Science or special degree program with an emphasis in Construction Management, Construction Technology, or Inspection Technology', 'EDUCATION_MAJOR')]
# Tokens [('"', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('Building', 'EXP_JOB_CLASS_TITLE', 3), ('Inspector', 'EXP_JOB_CLASS_TITLE', 1), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('.', '', 2), ('One', 'EXPERIENCE_LENGTH', 3), ('year', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('Building', 'EXP_JOB_CLASS_TITLE', 3), ('Mechanical', 'EXP_JOB_CLASS_TITLE', 1), ('Inspector', 'EXP_JOB_CLASS_TITLE', 1), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('may', '', 2), ('be', '', 2), ('substituted', '', 2), ('for', '', 2), ('one', '', 2), ('year', '', 2), ('of', '', 2), ('Building', '', 2), ('Inspector', '', 2), ('experience', '', 2), ('lacking', '', 2), (';', '', 2), ('or', '', 2), ('Graduation', '', 2), ('from', '', 2), ('an', '', 2), ('accredited', '', 2), ('four', 'EDUCATION_YEARS', 3), ('-', 'EDUCATION_YEARS', 1), ('year', 'EDUCATION_YEARS', 1), ('college', 'SCHOOL_TYPE', 3), ('or', 'SCHOOL_TYPE', 1), ('university', 'SCHOOL_TYPE', 1), ('with', '', 2), ('a', '', 2), ('degree', '', 2), ('in', '', 2), ('Industrial', 'EDUCATION_MAJOR', 3), ('Technology', 'EDUCATION_MAJOR', 1), (',', 'EDUCATION_MAJOR', 1), ('Industrial', 'EDUCATION_MAJOR', 1), ('Science', 'EDUCATION_MAJOR', 1), ('or', 'EDUCATION_MAJOR', 1), ('special', 'EDUCATION_MAJOR', 1), ('degree', 'EDUCATION_MAJOR', 1), ('program', 'EDUCATION_MAJOR', 1), ('with', 'EDUCATION_MAJOR', 1), ('an', 'EDUCATION_MAJOR', 1), ('emphasis', 'EDUCATION_MAJOR', 1), ('in', 'EDUCATION_MAJOR', 1), ('Construction', 'EDUCATION_MAJOR', 1), ('Management', 'EDUCATION_MAJOR', 1), (',', 'EDUCATION_MAJOR', 1), ('Construction', 'EDUCATION_MAJOR', 1), ('Technology', 'EDUCATION_MAJOR', 1), (',', 'EDUCATION_MAJOR', 1), ('or', 'EDUCATION_MAJOR', 1), ('Inspection', 'EDUCATION_MAJOR', 1), ('Technology', 'EDUCATION_MAJOR', 1), ('may', '', 2), ('be', '', 2), ('substituted', '', 2), ('for', '', 2), ('up', '', 2), ('to', '', 2), ('one', '', 2), ('year', '', 2), ('of', '', 2), ('required', '', 2), ('Building', '', 2), ('Inspector', '', 2), ('experience', '', 2), ('.', '', 2), ('"', '', 2)]
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Senior Wastewater Treatment Operator', 'EXP_JOB_CLASS_TITLE'), ('managing employees engaged in wastewater treatment operations', 'EXP_JOB_CLASS_FUNCTION'), ('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Environmental Engineering Associate III', 'EXP_JOB_CLASS_TITLE'), ('managing employees engaged in wastewater treatment operations', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('"', '', 2), ('1', '', 2), ('.', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('supervisory', '', 2), ('experience', '', 2), ('in', '', 2), ('a', '', 2), ('class', '', 2), ('at', '', 2), ('the', '', 2), ('level', '', 2), ('of', '', 2), ('a', '', 2), ('Senior', 'EXP_JOB_CLASS_TITLE', 3), ('Wastewater', 'EXP_JOB_CLASS_TITLE', 1), ('Treatment', 'EXP_JOB_CLASS_TITLE', 1), ('Operator', 'EXP_JOB_CLASS_TITLE', 1), (',', '', 2), ('managing', 'EXP_JOB_CLASS_FUNCTION', 3), ('employees', 'EXP_JOB_CLASS_FUNCTION', 1), ('engaged', 'EXP_JOB_CLASS_FUNCTION', 1), ('in', 'EXP_JOB_CLASS_FUNCTION', 1), ('wastewater', 'EXP_JOB_CLASS_FUNCTION', 1), ('treatment', 'EXP_JOB_CLASS_FUNCTION', 1), ('operations', 'EXP_JOB_CLASS_FUNCTION', 1), (';', '', 2), ('or', '', 2), ('2', '', 2), ('.', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('supervisory', '', 2), ('and', '', 2), ('process', '', 2), ('engineering', '', 2), ('experience', '', 2), ('in', '', 2), ('a', '', 2), ('class', '', 2), ('at', '', 2), ('the', '', 2), ('level', '', 2), ('of', '', 2), ('an', '', 2), ('Environmental', 'EXP_JOB_CLASS_TITLE', 3), ('Engineering', 'EXP_JOB_CLASS_TITLE', 1), ('Associate', 'EXP_JOB_CLASS_TITLE', 1), ('III', 'EXP_JOB_CLASS_TITLE', 1), (',', '', 2), ('managing', 'EXP_JOB_CLASS_FUNCTION', 3), ('employees', 'EXP_JOB_CLASS_FUNCTION', 1), ('engaged', 'EXP_JOB_CLASS_FUNCTION', 1), ('in', 'EXP_JOB_CLASS_FUNCTION', 1), ('wastewater', 'EXP_JOB_CLASS_FUNCTION', 1), ('treatment', 'EXP_JOB_CLASS_FUNCTION', 1), ('operations', 'EXP_JOB_CLASS_FUNCTION', 1), ('.', '', 2), ('"', '', 2)]
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('Principal Clerk', 'EXP_JOB_CLASS_TITLE')]
# Tokens [('"', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('as', '', 2), ('a', '', 2), ('Principal', 'EXP_JOB_CLASS_TITLE', 3), ('Clerk', 'EXP_JOB_CLASS_TITLE', 1), ('or', '', 2), ('in', '', 2), ('a', '', 2), ('position', '', 2), ('at', '', 2), ('that', '', 2), ('level', '', 2), ('which', '', 2), ('provides', '', 2), ('experience', '', 2), ('in', '', 2), ('supervision', '', 2), ('of', '', 2), ('clerical', '', 2), ('personnel', '', 2), ('.', '', 2), (' ', '', 2), ('NOTE', '', 2), ('Applicants', '', 2), ('who', '', 2), ('lack', '', 2), ('six', '', 2), ('months', '', 2), ('or', '', 2), ('less', '', 2), ('of', '', 2), ('the', '', 2), ('required', '', 2), ('experience', '', 2), ('may', '', 2), ('file', '', 2), ('for', '', 2), ('this', '', 2), ('examination', '', 2), ('.', '', 2), ('However', '', 2), (',', '', 2), ('they', '', 2), ('can', '', 2), ('not', '', 2), ('be', '', 2), ('appointed', '', 2), ('until', '', 2), ('the', '', 2), ('full', '', 2), ('experience', '', 2), ('requirement', '', 2), ('is', '', 2), ('completed', '', 2), ('.', '', 2), ('"', '', 2)]
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('helper to a journey-level electrical worker', 'EXP_JOB_CLASS_TITLE'), ('construction, installation, maintenance, and repair of fiber optic and lead or plastic sheathed communications type cables and control lines containing control, telemetering or telephone circuits', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('"', '', 2), ('/MINIMUM', '', 2), ('QUALIFICAITON', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('helper', 'EXP_JOB_CLASS_TITLE', 3), ('to', 'EXP_JOB_CLASS_TITLE', 1), ('a', 'EXP_JOB_CLASS_TITLE', 1), ('journey', 'EXP_JOB_CLASS_TITLE', 1), ('-', 'EXP_JOB_CLASS_TITLE', 1), ('level', 'EXP_JOB_CLASS_TITLE', 1), ('electrical', 'EXP_JOB_CLASS_TITLE', 1), ('worker', 'EXP_JOB_CLASS_TITLE', 1), ('in', '', 2), ('the', '', 2), ('construction', 'EXP_JOB_CLASS_FUNCTION', 3), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('installation', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('maintenance', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('repair', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('fiber', 'EXP_JOB_CLASS_FUNCTION', 1), ('optic', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('lead', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('plastic', 'EXP_JOB_CLASS_FUNCTION', 1), ('sheathed', 'EXP_JOB_CLASS_FUNCTION', 1), ('communications', 'EXP_JOB_CLASS_FUNCTION', 1), ('type', 'EXP_JOB_CLASS_FUNCTION', 1), ('cables', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('control', 'EXP_JOB_CLASS_FUNCTION', 1), ('lines', 'EXP_JOB_CLASS_FUNCTION', 1), ('containing', 'EXP_JOB_CLASS_FUNCTION', 1), ('control', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), 
', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('journey-level fire sprinkler fitter', 'EXP_JOB_CLASS_TITLE'), ('installing fire sprinklers and standpipe systems in commercial facilities using the National Fire Protection Association standards', 'EXP_JOB_CLASS_FUNCTION'), ('Four years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('fire sprinkler inspector', 'EXP_JOB_CLASS_TITLE'), ('having jurisdictional authority by a City, County or State agency on commercial facility fire sprinkler and standpipe installations using the National Fire Protection Association standards', 'EXP_JOB_CLASS_FUNCTION')]
# ...
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('Senior Survey Supervisor', 'EXP_JOB_CLASS_TITLE'), ('Four years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('Survey Supervisor', 'EXP_JOB_CLASS_TITLE')]
# Tokens [('1', '', 2), ('.', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('as', '', 2), ('a', '', 2), ('Senior', 'EXP_JOB_CLASS_TITLE', 3), ('Survey', 'EXP_JOB_CLASS_TITLE', 1), ('Supervisor', 'EXP_JOB_CLASS_TITLE', 1), (';', '', 2), ('or', '', 2), ('2', '', 2), ('.', '', 2), ('Four', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('with', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('as', '', 2), ('a', '', 2), ('Survey', 'EXP_JOB_CLASS_TITLE', 3), ('Supervisor', 'EXP_JOB_CLASS_TITLE', 1), ('.', '', 2)]
# Entities [('Four years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('fabrication, welding, altering, and assembling structural steel members and shapes', 'EXP_JOB_CLASS_FUNCTION')]
# Tokens [('"', '', 2), ('Four', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('in', '', 2), ('work', '', 2), ('involving', '', 2), ('all', '', 2), ('of', '', 2), ('the', '', 2), ('following', '', 2), ('areas', '', 2), (':', '', 2), ('fabrication', 'EXP_JOB_CLASS_FUNCTION', 3), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('welding', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('altering', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('assembling', 'EXP_JOB_CLASS_FUNCTION', 1), ('structural', 'EXP_JOB_CLASS_FUNCTION', 1), ('steel', 'EXP_JOB_CLASS_FUNCTION', 1), ('members', 'EXP_JOB_CLASS_FUNCTION', 1), ('and', 'EXP_JOB_CLASS_FUNCTION', 1), ('shapes', 'EXP_JOB_CLASS_FUNCTION', 1), ('.', '', 2), (' ', '', 2), ('"', '', 2)]
# Entities [('Three years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('Steam Plant Assistant', 'EXP_JOB_CLASS_TITLE'), ('City of Los Angeles', 'EXP_JOB_COMPANY'), ('Assistant Maintenance Mechanic', 'EXP_JOB_CLASS_TITLE')]
# Tokens [('"', '', 2), ('Three', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), 
 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('as', '', 2), ('a', '', 2), ('Risk', 'EXP_JOB_CLASS_TITLE', 3), ('Manager', 'EXP_JOB_CLASS_TITLE', 1), ('with', '', 2), ('in', '', 2), ('the', '', 2), ('City', 'EXP_JOB_COMPANY', 3), ('of', 'EXP_JOB_COMPANY', 1), ('Los', 'EXP_JOB_COMPANY', 1), ('Angeles', 'EXP_JOB_COMPANY', 1), ('providing', 'EXP_JOB_CLASS_FUNCTION', 3), ('advice', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('general', 'EXP_JOB_CLASS_FUNCTION', 1), ('counsel', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('litigation', 'EXP_JOB_CLASS_FUNCTION', 1), ('services', 'EXP_JOB_CLASS_FUNCTION', 1), ('regarding', 'EXP_JOB_CLASS_FUNCTION', 1), ('risk', 'EXP_JOB_CLASS_FUNCTION', 1), ('management', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('risk', 'EXP_JOB_CLASS_FUNCTION', 1), ('threat', 'EXP_JOB_CLASS_FUNCTION', 1), ('assessment', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('risk', 'EXP_JOB_CLASS_FUNCTION', 1), ('evaluation', 'EXP_JOB_CLASS_FUNCTION', 1), ('for', 'EXP_JOB_CLASS_FUNCTION', 1), ('a', 'EXP_JOB_CLASS_FUNCTION', 1), ('public', 'EXP_JOB_CLASS_FUNCTION', 1), ('safety', 'EXP_JOB_CLASS_FUNCTION', 1), ('organization', 'EXP_JOB_CLASS_FUNCTION', 1), (';', '', 2), ('or', '', 2), ('2', '', 2), ('.', '', 2), ('a', '', 2), (')', '', 2), ('Graduation', '', 2), ('from', '', 2), ('an', '', 2), ('accredited', '', 2), ('four', 'EDUCATION_YEARS', 3), ('-', 'EDUCATION_YEARS', 1), ('year', 'EDUCATION_YEARS', 1), ('college', 'SCHOOL_TYPE', 3), ('or', 'SCHOOL_TYPE', 1), ('university', 'SCHOOL_TYPE', 1), ('with', '', 2), ('a', '', 2), ('degree', '', 2), ('in', '', 2), ('business', 'EDUCATION_MAJOR', 3), (',', 'EDUCATION_MAJOR', 1), ('public', 'EDUCATION_MAJOR', 1), ('administration', 'EDUCATION_MAJOR', 1), (',', 'EDUCATION_MAJOR', 1), ('political', 'EDUCATION_MAJOR', 1), ('science', 'EDUCATION_MAJOR', 1), ('or', 'EDUCATION_MAJOR', 1), ('related', 'EDUCATION_MAJOR', 1), ('field', 'EDUCATION_MAJOR', 1), (';', '', 2), ('and', '', 2), ('b', '', 2), (')', '', 2), ('Four', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('professional', '', 2), ('experience', '', 2), ('providing', 'EXP_JOB_CLASS_FUNCTION', 3), ('advice', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('general', 'EXP_JOB_CLASS_FUNCTION', 1), ('counsel', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('litigation', 'EXP_JOB_CLASS_FUNCTION', 1), ('services', 'EXP_JOB_CLASS_FUNCTION', 1), ('regarding', 'EXP_JOB_CLASS_FUNCTION', 1), ('risk', 'EXP_JOB_CLASS_FUNCTION', 1), ('management', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('risk', 'EXP_JOB_CLASS_FUNCTION', 1), ('assessment', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('risk', 'EXP_JOB_CLASS_FUNCTION', 1), ('evaluation', 'EXP_JOB_CLASS_FUNCTION', 1), ('for', 'EXP_JOB_CLASS_FUNCTION', 1), ('a', 'EXP_JOB_CLASS_FUNCTION', 1), ('public', 'EXP_JOB_CLASS_FUNCTION', 1), ('safety', 'EXP_JOB_CLASS_FUNCTION', 1), ('organization', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('with', 'EXP_JOB_CLASS_FUNCTION', 1), ('two', '', 2), ('of', '', 2), ('the', '', 2), ('four', '', 2), ('years', '', 2), ('supervising', '', 2), ('staff', '', 2), ('engaged', '', 2), ('in', '', 2), ('the', '', 2), ('administration', '', 2), ('of', '', 2), ('a', '', 2), ('risk', '', 2), ('management', '', 2), ('program', '', 2), ('.', '', 2), (' ', '', 2), ('"', '', 2)]
# Entities [('Two years', 'EXPERIENCE_LENGTH'), ('full-time', 'FULL_TIME_PART_TIME'), ('installation, construction, repair, operation, or maintenance of electronic communications equipment', 'EXP_JOB_CLASS_FUNCTION'), ('two-year', 'EDUCATION_YEARS'), ('electronics from', 'EDUCATION_MAJOR'), ('college or trade school', 'SCHOOL_TYPE'), ('30 semester', 'EXPERIENCE_LENGTH'), ('electronics field of concentration', 'COURSE_SUBJECT'), ('college or trade school', 'SCHOOL_TYPE'), ('electronics', 'EDUCATION_MAJOR'), ('24 weeks', 'EXPERIENCE_LENGTH')]
# Tokens [('"', '', 2), ('1', '', 2), ('.', '', 2), ('Two', 'EXPERIENCE_LENGTH', 3), ('years', 'EXPERIENCE_LENGTH', 1), ('of', '', 2), ('full', 'FULL_TIME_PART_TIME', 3), ('-', 'FULL_TIME_PART_TIME', 1), ('time', 'FULL_TIME_PART_TIME', 1), ('paid', '', 2), ('experience', '', 2), ('in', '', 2), ('the', '', 2), ('installation', 'EXP_JOB_CLASS_FUNCTION', 3), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('construction', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('repair', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('operation', 'EXP_JOB_CLASS_FUNCTION', 1), (',', 'EXP_JOB_CLASS_FUNCTION', 1), ('or', 'EXP_JOB_CLASS_FUNCTION', 1), ('maintenance', 'EXP_JOB_CLASS_FUNCTION', 1), ('of', 'EXP_JOB_CLASS_FUNCTION', 1), ('electronic', 'EXP_JOB_CLASS_FUNCTION', 1), ('communications', 'EXP_JOB_CLASS_FUNCTION', 1), ('equipment', 'EXP_JOB_CLASS_FUNCTION', 1), (';', '', 2), ('or', '', 2), ('2', '', 2), ('.', '', 2), ('Successful', '', 2), ('completion', '', 2), ('of', '', 2), (':', '', 2), ('a', '', 2), (')', '', 2), ('A', '', 2), ('two', 'EDUCATION_YEARS', 3), ('-', 'EDUCATION_YEARS', 1), ('year', 'EDUCATION_YEARS', 1), ('program', '', 2), ('in', '', 2), ('electronics', 'EDUCATION_MAJOR', 3), ('from', 'EDUCATION_MAJOR', 1), ('an', '', 2), ('accredited', '', 2), ('college', 'SCHOOL_TYPE', 3), ('or', 'SCHOOL_TYPE', 1), ('trade', 'SCHOOL_TYPE', 1), ('school', 'SCHOOL_TYPE', 1), (';', '', 2), ('or', '', 2), ('b', '', 2), (')', '', 2), ('30', 'EXPERIENCE_LENGTH', 3), ('semester', 'EXPERIENCE_LENGTH', 1), ('or', '', 2), ('45', '', 2), ('quarter', '', 2), ('units', '', 2), ('in', '', 2), ('an', '', 2), ('electronics', 'COURSE_SUBJECT', 3), ('field', 'COURSE_SUBJECT', 1), ('of', 'COURSE_SUBJECT', 1), ('concentration', 'COURSE_SUBJECT', 1), ('from', '', 2), ('an', '', 2), ('accredited', '', 2), ('college', 'SCHOOL_TYPE', 3), ('or', 'SCHOOL_TYPE', 1), ('trade', 'SCHOOL_TYPE', 1), ('school', 'SCHOOL_TYPE', 1), (';', '', 2), ('or', '', 2), ('c', '', 2), (')', '', 2), ('A', '', 2), ('military', '', 2), ('electronics', 'EDUCATION_MAJOR', 3), ('technician', '', 2), ('course', '', 2), ('of', '', 2), ('24', 'EXPERIENCE_LENGTH', 3), ('weeks', 'EXPERIENCE_LENGTH', 1), ('or', '', 2), ('longer', '', 2), ('.', '', 2), (' ', '', 2), ('"', '', 2)]

# %% [markdown]
# ## Extract using NER model

# %%
# Extract data by ner model
def ner_extract(nlp,text):
    doc = nlp(text)
    return [(ent.text, ent.label_) for ent in doc.ents]

# Extract requirements 
df['temp_req'] = df['req_list'].apply(lambda x: ner_extract(nlp,x))

# %%
df.head(5)
# Out:
#                                            File_Name  \
# 0        PARK MAINTENANCE SUPERVISOR 3145 102618.txt
# 1        PARK MAINTENANCE SUPERVISOR 3145 102618.txt
# 2  ENVIRONMENTAL ENGINEER  7872 082616 REV 090116...
# 3  MOTION PICTURE AND TELEVISION MANAGER 1789 111...
# 4               HOUSING INVESTIGATOR 8516 062918.txt
#
#                                             job_info  \
# 0  PARK MAINTENANCE SUPERVISOR\n\nClass Code:    ...
# 1  PARK MAINTENANCE SUPERVISOR\n\nClass Code:    ...
# 2  ENVIRONMENTAL ENGINEER \n\nClass Code:       7...
# 3  MOTION PICTURE AND TELEVISION MANAGER\n\n\nCla...
# 4  HOUSING INVESTIGATOR\n\nClass Code:       8516...
#
#                          JOB_CLASS_TITLE JOB_CLASS_NO OPEN_DATE EXAM_TYPE  \
# 0            PARK MAINTENANCE SUPERVISOR         3145  10-26-18      OPEN
# 1            PARK MAINTENANCE SUPERVISOR         3145  10-26-18      OPEN
# 2                 ENVIRONMENTAL ENGINEER         7872  08-26-16      OPEN
# 3  MOTION PICTURE AND TELEVISION MANAGER         1789  11-17-17      OPEN
# 4                   HOUSING INVESTIGATOR         8516  06-29-18      OPEN
#
#     ENTRY_SALARY_GEN ENTRY_SALARY_DWP  \
# 0               None  83,728 - 88,405
# 1               None  83,728 - 88,405
# 2   89,637 - 127,555             None
# 3  120,080 - 175,559             None
# 4    59,487 - 86,965             None
#
#                                           JOB_DUTIES DRIVERS_LICENSE_REQ  \
# 0  A Park Maintenance Supervisor directly supervi...                   R
# 1  A Park Maintenance Supervisor directly supervi...                   R
# 2  An Environmental Engineer performs responsible...                   R
# 3  A Motion Picture and Television Manager plans,...                   R
# 4  A Housing Investigator conducts preliminary an...                   R
#
#   DRIV_LIC_TYPE                                        Req_section  \
# 0          None  1. Two years of full-time paid experience as a...
# 1          None  1. Two years of full-time paid experience as a...
# 2          None  Two years of full-time paid professional envir...
# 3          None  1. Graduation from an accredited four-year col...
# 4          None  1. Graduation from an accredited four-year col...
#
#                                             req_list  REQUIREMENT_SET_ID  \
# 0  1. Two years of full-time paid experience as a...                   1
# 1  2. One year full-time paid experience as noted...                   2
# 2  Two years of full-time paid professional envir...                   1
# 3  1. Graduation from an accredited four-year col...                   1
# 4  1. Graduation from an accredited four-year col...                   1
#
#                                             temp_req
# 0  [(Two years, EXPERIENCE_LENGTH), (full-time, F...
# 1  [(One year, EXPERIENCE_LENGTH), (full-time, FU...
# 2  [(Two years, EXPERIENCE_LENGTH), (full-time, F...
# 3  [(four-year, EDUCATION_YEARS), (college or uni...
# 4  [(four-year, EDUCATION_YEARS), (college or uni...

# %% [markdown]
# # Create CSV

# %% [markdown]
# ##  Flatten the temp_req column

# %%
# Extract one column from list
def extract_col(l,col):
    result = [x[0] for x in l if x[1]==col]
    return None if result==[] else result[0]

# Extract colums from temp_req column
def extract_col_df(df,col):
    df[col]=df['temp_req'].apply(lambda x: extract_col(x,col))
    return df

# %%
# Extract coulums in df
cols_to_extract = ['EDUCATION_YEARS', 'SCHOOL_TYPE' ,'EDUCATION_MAJOR', 'EXPERIENCE_LENGTH' ,\
                   'FULL_TIME_PART_TIME','EXP_JOB_CLASS_TITLE', 'EXP_JOB_CLASS_ALT_RESP',\
                   'EXP_JOB_CLASS_FUNCTION', 'EXP_JOB_CLASS_ADDITIONAL_FUNCTION','COURSE_COUNT',\
                   'COURSE_LENGTH', 'COURSE_SUBJECT', 'MISC_COURSE_DETAILS', 'EXP_JOB_COMPANY',\
                   'DEGREE NAME', 'EXP_JOB_CLASS_ALT_JOB_TITLE', 'REQUIRED_CERTIFICATE',\
                   'CERTIFICATE_ISSUED_BY','COURSE_TITLE', 'REQUIRED_EXAM_PASS', 'EXPERIENCE_EXTRA_DETAILS']

for col in cols_to_extract:
    df = extract_col_df(df,col)

# %%
col_orders = ['File_Name','JOB_CLASS_TITLE', 'JOB_CLASS_NO', 
                 'REQUIREMENT_SET_ID',
                 'JOB_DUTIES','EDUCATION_YEARS', 'SCHOOL_TYPE',
                 'EDUCATION_MAJOR', 'DEGREE NAME','EXPERIENCE_LENGTH',
                 'FULL_TIME_PART_TIME',
                 'EXP_JOB_CLASS_TITLE', 'EXP_JOB_CLASS_FUNCTION',
                 'EXP_JOB_COMPANY','EXP_JOB_CLASS_ALT_JOB_TITLE',
                 'EXP_JOB_CLASS_ALT_RESP', 'COURSE_COUNT',
                 'COURSE_LENGTH', 'COURSE_SUBJECT',
                 'REQUIRED_CERTIFICATE','CERTIFICATE_ISSUED_BY',
                 'DRIVERS_LICENSE_REQ', 'DRIV_LIC_TYPE',
                 'EXAM_TYPE','ENTRY_SALARY_GEN','ENTRY_SALARY_DWP','OPEN_DATE']

df[col_orders].to_csv('./jobs.csv', index=None)
