# %% [markdown]
# Lecture Notes:
#
# 1. General
# Y = f(X)+epsi
# - Reducible and irreducible errors
# - MSE
# - Bias and variance balance
# - Sample size: n
# - Predictor dim: p
#
#
# 2. Linear regression
# Y = b0+b1*X+epsi
# - Coefficients
# - TSS (Total sum of square): depends on Y
# - RSS (Residual sum of square): least square
# - SE (Standard Error): depends on X and epsi; for each coeff; compute by using RSE (or RSS)
# - t-stats: depends on coeff and its SE; for each coeff
# - p-value: for each coeff;large p indicates coeff=0
# - Confidence interval: for each coeff
# - RSE (Residual standard error): depends on RSS,n,p; measures the standard deviation of epsi
# - R-square (0-1): depends on TSS and RSS; measures the propotion of variance explained
#
# 3. Multiple Linear regression
# Y = b0+b1*X1+b2*X2+...(bp-1)*Xp+epsi
# - F-stats: depends on TSS,RSS,n,p; for all coeff
# - Variable selection: forward selection, backward selection, mixed selection
# - Prediction interval
# - Qualitative predictors (0 or 1)
#
# 4. Potential problems
# - Non-linearity data: use residual plots to identify dicernible pattern
# - Correlation of error terms: use residual plot as a function of time to idenfity dicernible pattern
# - Non-constant variance of error terms: use residual plot to identify a funnel shape; transform Y using concave functions
# - Outliers: use residual plot to eyeball them
# - High leverage points: compute leverage stats and compare with (1+p)/n; depends on X and n
# - Collinearity: look at the correlation matrix of the predictors; compute VIF (variance inflation factor); VIF=1 indicates no collinearity, VIF>5 or >10 indicates collinearity; drop one predictor or combine them into a new one.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
import findspark
from pyspark import SparkContext
from pyspark.sql import SparkSession, DataFrame, DataFrameReader
from pyspark.ml.regression import LinearRegression, LinearRegressionModel, LinearRegressionSummary
from pyspark.mllib.regression import LabeledPoint
from pyspark.ml.feature import VectorAssembler

# %matplotlib inline
findspark.init("/Users/lhd0430/Downloads/spark")

# %%
# Creat spark session
spark = SparkSession.builder \
   .master("local") \
   .appName("Linear Regression Model") \
   .config("spark.executor.memory", "1gb") \
   .getOrCreate()

# %%
# Load data as pyspark.sql.DataFrame
data = spark.read.csv("../data/Boston.csv", header=True, inferSchema=True)
data.cache()
print(data.count())
data.dropna()
print(data.count())
# Out:
# 506
# 506

# %%
# Convert feature to vector type
vecAssembler = VectorAssembler(inputCols=["lstat"], outputCol="features")
df = vecAssembler.transform(data)

# %%
data.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# black   -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# medv    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               dis       rad       tax   ptratio     black     lstat      medv
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# black    0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# medv     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
# LR

# Fit model
lr = LinearRegression(featuresCol="features", labelCol="medv")
ml = lr.fit(df)

# %%
type(ml)
# Out:
# pyspark.ml.regression.LinearRegressionModel

# %%
# Show info
# Note: metrics are limited in sklearn
print(ml.coef)
print(ml2.intercept_)
print(r2_score(Y,Y_pred))
print(mean_squared_error(Y,Y_pred)) # MSE ~ RSE^2

# Plot
fig, axes = plt.subplots(1,2)
axes[0].plot(X,Y,'o')
axes[0].plot(X,Y_pred,'r')
axes[1].plot(X,Y-Y_pred,'.')
plt.show()
# Out:
# [[-0.95004935]]
# [ 34.55384088]
# 0.544146297586
# 38.4829672299

# %%
# MLR - statsmodels

# Fit data
mml1 = smf.ols('medv~lstat+age',data=data).fit()
# mml1 = smf.ols('medv~ lstat+ I(lstat ** 2.0)',data=data).fit()
# mml1 = smf.ols('medv~lstat*age',data=data).fit()

# Show info
print(mml1.summary())
# Compute MSE (or RSS) and thus we can have RSE
print((mml1.resid**2).sum()/len(data.medv))
# Compute VIF
est_age = smf.ols('age~lstat+dis', data=data).fit()
est_lstat = smf.ols('lstat~age+dis', data=data).fit()
est_dis = smf.ols('dis~age+lstat', data=data).fit()
print(1/(1-est_age.rsquared)) # VIF of age
print(1/(1-est_lstat.rsquared)) # VIF of lstat
print(1/(1-est_dis.rsquared)) # VIF of dis

# Plot
fig = plt.figure()
ax1 = fig.add_subplot(121,projection='3d')
ax2 = fig.add_subplot(122,projection='3d')
ax1.scatter3D(data.lstat,data.age,data.medv)
ax1.scatter3D(data.lstat,data.age,mml1.predict(),c='r')
ax2.scatter3D(data.lstat,data.age,mml1.resid)
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   medv   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     309.0
# Date:                Tue, 30 Jan 2018   Prob (F-statistic):           2.98e-88
# Time:                        12:44:01   Log-Likelihood:                -1637.5
# No. Observations:                 506   AIC:                             3281.
# Df Residuals:                     503   BIC:                             3294.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     33.2228      0.731     45.458      0.000        31.787    34.659
# lstat         -1.0321      0.048    -21.416      0.000        -1.127    -0.937
# age            0.0345      0.012      2.826      0.005         0.011     0.059
# ==============================================================================
# Omnibus:                      124.288   Durbin-Watson:                   0.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              244.026
# Skew:                           1.362   Prob(JB):                     1.02e-53
# Kurtosis:                       5.038   Cond. No.                         201.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 37.8816770924127
# 2.70250308569
# 1.58158354226
# 2.2868717704

# %%
# MLR - sklearn

# Fit model
mml2 = LinearRegression(normalize=True)
Y = pd.DataFrame(data.medv)
X = data[['lstat','age']].as_matrix()
mml2.fit(X,Y)
Y_pred = mml2.predict(X)

# Show info
# Note: metrics are limited in sklearn
print(mml2.coef_)
print(mml2.intercept_)
print(r2_score(Y,Y_pred))
print(mean_squared_error(Y,Y_pred)) # MSE ~ RSE^2
# VIF follows the same algorithm as in statsmodels case

# Plot
fig = plt.figure();
ax1 = fig.add_subplot(121,projection="3d")
ax2 = fig.add_subplot(122,projection="3d")
ax1.scatter3D(X[:,0],X[:,1],Y)
ax1.scatter3D(X[:,0],X[:,1],Y_pred,c="r")
ax2.scatter3D(X[:,0],X[:,1],Y-Y_pred)
plt.show()
# Out:
# [[-1.03206856  0.03454434]]
# [ 33.22276053]
# 0.551268937942
# 37.8816770924

# %%
dir(mml2)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_center_data',
#  '_decision_function',
#  '_estimator_type',
#  '_get_param_names',
#  '_residues',
#  '_set_intercept',
#  'coef_',
#  'copy_X',
#  'decision_function',
#  'fit',
#  'fit_intercept',
#  'get_params',
#  'intercept_',
#  'n_jobs',
#  'normalize',
#  'predict',
#  'rank_',
#  'residues_',
#  'score',
#  'set_params',
#  'singular_']
